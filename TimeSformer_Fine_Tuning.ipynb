# %% [markdown]
# <a href="https://colab.research.google.com/github/Jubayer934/Sign_language_Detection/blob/main/TimeSformer_Fine_Tuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ✅ Step 1: Install Required Libraries

# %%
pip install transformers datasets accelerate timm decord
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.52.4)
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (2.14.4)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.7.0)
# Requirement already satisfied: timm in /usr/local/lib/python3.11/dist-packages (1.0.15)
# Collecting decord
#   Downloading decord-0.6.0-py3-none-manylinux2010_x86_64.whl.metadata (422 bytes)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.33.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec>=2021.11.1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.11.1->datasets) (2025.3.2)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.15)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from timm) (0.21.0+cu124)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.20.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (1.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.6.15)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision->timm) (11.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# Downloading decord-0.6.0-py3-none-manylinux2010_x86_64.whl (13.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 82.3 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 55.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 29.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 22.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.9 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 9.1 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 101.9 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, decord, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed decord-0.6.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %% [markdown]
# ✅ Step 2: Load Pretrained ViViT Model + Feature Extractor

# %%
from transformers import TimesformerForVideoClassification, AutoFeatureExtractor

# Load feature extractor and pretrained TimeSformer model (fine-tuned on Kinetics-400)
model = TimesformerForVideoClassification.from_pretrained("facebook/timesformer-base-finetuned-k400")
# Use AutoFeatureExtractor instead of TimesformerFeatureExtractor
feature_extractor = AutoFeatureExtractor.from_pretrained("facebook/timesformer-base-finetuned-k400")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/22.7k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/486M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/412 [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/transformers/models/videomae/feature_extraction_videomae.py:30: FutureWarning: The class VideoMAEFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use VideoMAEImageProcessor instead.
#   warnings.warn(

# %% [markdown]
#  Load the Dataset

# %% [markdown]
# What frame size the model expects (e.g., 224×224) <br>
# How many frames (e.g., 16 frames from a video) <br>
# What kind of normalization/scaling to apply

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import zipfile
import os

# Path to the zip file in Drive
zip_path = "/content/drive/MyDrive/ModelTrain/signlanguage/dataset/sign.zip"

# Unzip it to /content/
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall("/content/sign_dataset")

# Set dataset path
dataset_path = "/content/sign_dataset"

# %%
import os

# List top-level files/folders
print(os.listdir("/content/sign_dataset"))

# If it's nested, explore further:
for root, dirs, files in os.walk("/content/sign_dataset"):
    print("Root:", root)
    print("Dirs:", dirs)
    print("Files:", files[:5])  # just print the first 5 files
    print("===")
# Out:
# ['Answer', 'Elephant', 'cold', 'Duck', 'All of you', 'cut off', 'Follow', 'Fear', 'forget', 'Dog', 'Everyone', 'Everyday', 'Ask', 'feel hot', 'forgive', 'Collectin', 'Feelings', 'Another', 'Chicken', 'come', 'brother', 'Fast', 'Cow', 'Difficalty', 'Cat', 'Around', 'Carefully', 'Crow', 'A lot', 'Crocodile']
# Root: /content/sign_dataset
# Dirs: ['Answer', 'Elephant', 'cold', 'Duck', 'All of you', 'cut off', 'Follow', 'Fear', 'forget', 'Dog', 'Everyone', 'Everyday', 'Ask', 'feel hot', 'forgive', 'Collectin', 'Feelings', 'Another', 'Chicken', 'come', 'brother', 'Fast', 'Cow', 'Difficalty', 'Cat', 'Around', 'Carefully', 'Crow', 'A lot', 'Crocodile']
# Files: []
# ===
# Root: /content/sign_dataset/Answer
# Dirs: []
# Files: ['s_34_w_124_a_30.mp4', 's_52_w_124_a_30.mp4', 's_14_w_124_a_30.mp4', 's_47_w_124_a_30.mp4', 's_40_w_124_a_30.mp4']
# ===
# Root: /content/sign_dataset/Elephant
# Dirs: []
# Files: ['s_51_w_65_s_90.mp4', 's_35_w_065_a_90.mp4', 's_26_w_65_s_90.mp4', 's_39_w_065_a_90.mp4', 's_34_w_065_a_90.mp4']
# ===
# Root: /content/sign_dataset/cold
# Dirs: []
# Files: ['s_34_w_117_a_30.mp4', 's_40_w_117_a_30.mp4', 's_41_w_117_a_30.mp4', 's_14_w_117_a_30.mp4', 's_54_w_117_a_30.mp4']
# ===
# Root: /content/sign_dataset/Duck
# Dirs: []
# Files: ['s_51_w_58_s_90.mp4', 's_26_w_58_s_90.mp4', 's_38_w_058_a_90.mp4', 's_36_w_058_a_90.mp4', 's_34_w_058_a_90.mp4']
# ===
# Root: /content/sign_dataset/All of you
# Dirs: []
# Files: ['s_14_w_104_a_30.mp4', 's_55_w_104_a_30.mp4', 's_11_w_104_a_30.mp4', 's_34_w_104_a_30.mp4', 's_54_w_104_a_30.mp4']
# ===
# Root: /content/sign_dataset/cut off
# Dirs: []
# Files: ['s_11_w_098_a_30.mp4', 's_54_w_098_a_30.mp4', 's_41_w_098_a_30.mp4', 's_47_w_098_a_30.mp4', 's_55_w_098_a_30.mp4']
# ===
# Root: /content/sign_dataset/Follow
# Dirs: []
# Files: ['s_34_w_044_a_30.mp4', 's_47_w_094_a_30.mp4', 's_41_w_094_a_30.mp4', 's_35_w_094_a_30.mp4', 's_46_w_094_a_30.mp4']
# ===
# Root: /content/sign_dataset/Fear
# Dirs: []
# Files: ['s_45_w_089_a_30.mp4', 's_41_w_089_a_30.mp4', 's_40_w_089_a_30.mp4', 's_43_w_089_a_30.mp4', 's_44_w_089_a_30.mp4']
# ===
# Root: /content/sign_dataset/forget
# Dirs: []
# Files: ['s_40_w_030_a_30.mp4', 's_53_w_030_a_30.mp4', 's_14_w_030_a_30.mp4', 's_52_w_030_a_30.mp4', 's_11_w_030_a_30.mp4']
# ===
# Root: /content/sign_dataset/Dog
# Dirs: []
# Files: ['s_36_w_053_a_90.mp4', 's_38_w_053_a_90.mp4', 's_51_w_53_s_90.mp4', 's_18_w_053_a_90.mp4', 's_35_w_053_a_90.mp4']
# ===
# Root: /content/sign_dataset/Everyone
# Dirs: []
# Files: ['s_41_w_084_a_30.mp4', 's_54_w_084_a_30.mp4', 's_49_w_084_a_30.mp4', 's_35_w_084_a_30 (3).mp4', 's_42_w_084_a_30 (5).mp4']
# ===
# Root: /content/sign_dataset/Everyday
# Dirs: []
# Files: ['s_26_w_78_s_90.mp4', 's_50_w_078_a_90.mp4', 's_37_w_078_a_90.mp4', 's_18_w_078_a_90.mp4', 's_35_w_078_a_90.mp4']
# ===
# Root: /content/sign_dataset/Ask
# Dirs: []
# Files: ['s_44_w_093_a_30.mp4', 's_34_w_043_a_30.mp4', 's_42_w_093_a_30.mp4', 's_54_w_093_a_30.mp4', 's_47_w_093_a_30.mp4']
# ===
# Root: /content/sign_dataset/feel hot
# Dirs: []
# Files: ['s_53_w_118_a_30.mp4', 's_14_w_118_a_30.mp4', 's_41_w_118_a_30.mp4', 's_55_w_118_a_30.mp4', 's_40_w_118_a_30.mp4']
# ===
# Root: /content/sign_dataset/forgive
# Dirs: []
# Files: ['s_56_w_103_a_30.mp4', 's_54_w_103_a_30.mp4', 's_41_w_103_a_30.mp4', 's_47_w_103_a_30.mp4', 's_53_w_103_a_30.mp4']
# ===
# Root: /content/sign_dataset/Collectin
# Dirs: []
# Files: ['s_35_w_073_a_90.mp4', 's_37_w_073_a_90.mp4', 's_18_w_073_a_90.mp4', 's_34_w_073_a_90.mp4', 's_26_w_73_s_90.mp4']
# ===
# Root: /content/sign_dataset/Feelings
# Dirs: []
# Files: ['s_46_w_086_a_30.mp4', 's_45_w_086_a_30.mp4', 's_54_w_086_a_30.mp4', 's_44_w_086_a_30.mp4', 's_43_w_086_a_30.mp4']
# ===
# Root: /content/sign_dataset/Another
# Dirs: []
# Files: ['s_41_w_083_a_30.mp4', 's_35_w_083_a_30.mp4', 's_44_w_083_a_30.mp4', 's_47_w_083_a_30.mp4', 's_40_w_083_a_30.mp4']
# ===
# Root: /content/sign_dataset/Chicken
# Dirs: []
# Files: ['s_34_w_059_a_90.mp4', 's_26_w_59_s_90.mp4', 's_38_w_059_a_90.mp4', 's_35_w_059_a_90.mp4', 's_50_w_059_a_90.mp4']
# ===
# Root: /content/sign_dataset/come
# Dirs: []
# Files: ['s_54_w_099_a_30.mp4', 's_55_w_099_a_30.mp4', 's_11_w_099_a_30.mp4', 's_52_w_099_a_30.mp4', 's_41_w_099_a_30.mp4']
# ===
# Root: /content/sign_dataset/brother
# Dirs: []
# Files: ['s_14_w_125_a_30.mp4', 's_53_w_125_a_30.mp4', 's_47_w_125_a_30.mp4', 's_56_w_125_a_30.mp4', 's_40_w_125_a_30.mp4']
# ===
# Root: /content/sign_dataset/Fast
# Dirs: []
# Files: ['s_43_w_095_a_30.mp4', 's_47_w_095_a_30.mp4', 's_34_w_045_a_30.mp4', 's_54_w_095_a_30.mp4', 's_35_w_095_a_30.mp4']
# ===
# Root: /content/sign_dataset/Cow
# Dirs: []
# Files: ['s_39_w_051_a_90.mp4', 's_38_w_051_a_90.mp4', 's_11_w_051_a_90.mp4', 's_34_w_051_a_90.mp4', 's_18_w_051_a_90.mp4']
# ===
# Root: /content/sign_dataset/Difficalty
# Dirs: []
# Files: ['s_34_w_040_a_30.mp4', 's_47_w_090_a_30.mp4', 's_43_w_090_a_30.mp4', 's_45_w_090_a_30.mp4', 's_34_w_090_a_30.mp4']
# ===
# Root: /content/sign_dataset/Cat
# Dirs: []
# Files: ['s_37_w_054_a_90.mp4', 's_34_w_054_a_90.mp4', 's_18_w_054_a_90.mp4', 's_50_w_054_a_90.mp4', 's_26_w_54_s_90.mp4']
# ===
# Root: /content/sign_dataset/Around
# Dirs: []
# Files: ['s_26_w_75_s_90.mp4', 's_51_w_75_s_90.mp4', 's_11_w_075_a_90.mp4', 's_35_w_075_a_90.mp4', 's_34_w_075_a_90.mp4']
# ===
# Root: /content/sign_dataset/Carefully
# Dirs: []
# Files: ['s_41_w_085_a_30.mp4', 's_35_w_085_a_30.mp4', 's_45_w_085_a_30.mp4', 's_43_w_085_a_30.mp4', 's_47_w_085_a_30.mp4']
# ===
# Root: /content/sign_dataset/Crow
# Dirs: []
# Files: ['s_26_w_60_s_90.mp4', 's_38_w_060_a_90.mp4', 's_39_w_060_a_90.mp4', 's_37_w_060_a_90.mp4', 's_11_w_060_a_90.mp4']
# ===
# Root: /content/sign_dataset/A lot
# Dirs: []
# Files: ['s_47_w_113_a_30.mp4', 's_11_w_113_a_30.mp4', 's_56_w_113_a_30.mp4', 's_54_w_113_a_30.mp4', 's_55_w_113_a_30.mp4']
# ===
# Root: /content/sign_dataset/Crocodile
# Dirs: []
# Files: ['s_36_w_068_a_90.mp4', 's_18_w_068_a_90.mp4', 's_39_w_068_a_90.mp4', 's_51_w_68_s_90.mp4', 's_34_w_068_a_90.mp4']
# ===

# %% [markdown]
# Step 3: Prepare Your Dataset List

# %%
import os

def get_video_paths_labels(root_dir):
    video_paths = []
    labels = []
    class_names = sorted(os.listdir(root_dir))
    label_map = {name: i for i, name in enumerate(class_names)}

    for cls in class_names:
        cls_folder = os.path.join(root_dir, cls)
        for fname in os.listdir(cls_folder):
            if fname.endswith('.mp4'):
                video_paths.append(os.path.join(cls_folder, fname))
                labels.append(label_map[cls])
    return video_paths, labels, label_map

video_paths, labels, label_map = get_video_paths_labels("/content/sign_dataset")

# %% [markdown]
# Step 4: Split Dataset Into Train & Validation

# %%
from sklearn.model_selection import train_test_split

train_paths, val_paths, train_labels, val_labels = train_test_split(
    video_paths, labels, test_size=0.25, stratify=labels, random_state=42
)

# %% [markdown]
# Step 5: Create Dataset Class

# %%
from torch.utils.data import Dataset
from decord import VideoReader, cpu
import numpy as np

class SignLanguageDataset(Dataset):
    def __init__(self, video_paths, labels, feature_extractor, num_frames=16):
        self.video_paths = video_paths
        self.labels = labels
        self.feature_extractor = feature_extractor
        self.num_frames = num_frames

    def __len__(self):
        return len(self.video_paths)

    def __getitem__(self, idx):
        vr = VideoReader(self.video_paths[idx], ctx=cpu(0))
        total_frames = len(vr)
        indices = np.linspace(0, total_frames-1, min(self.num_frames, total_frames)).astype(int)
        frames = vr.get_batch(indices).asnumpy()
        inputs = self.feature_extractor(list(frames), return_tensors="pt")
        return inputs["pixel_values"].squeeze(0), self.labels[idx]

# %% [markdown]
# Step 6: Create DataLoaders

# %%
from torch.utils.data import DataLoader

train_dataset = SignLanguageDataset(train_paths, train_labels, feature_extractor)
val_dataset = SignLanguageDataset(val_paths, val_labels, feature_extractor)

train_loader = DataLoader(train_dataset, batch_size=2, shuffle=True, num_workers=2)
val_loader = DataLoader(val_dataset, batch_size=2, shuffle=False, num_workers=2)

# %%
for i, (pixel_values, labels) in enumerate(train_loader):
    print(f"Batch {i+1}")
    print("Pixel values shape:", pixel_values.shape)  # Should be (B, T, C, H, W) or (B, 3, 16, 224, 224) after permute
    print("Labels:", labels)
    if i == 1:  # print only first 2 batches
        break
# Out:
# Batch 1
# Pixel values shape: torch.Size([2, 16, 3, 224, 224])
# Labels: tensor([ 2, 12])
# Batch 2
# Pixel values shape: torch.Size([2, 16, 3, 224, 224])
# Labels: tensor([16,  7])

# %%
for i, (pixel_values, labels) in enumerate(val_loader):
    print(f"Validation Batch {i+1}")
    print("Pixel values shape:", pixel_values.shape)
    print("Labels:", labels)
    if i == 1:
        break
# Out:
# Validation Batch 1
# Pixel values shape: torch.Size([2, 16, 3, 224, 224])
# Labels: tensor([20,  5])
# Validation Batch 2
# Pixel values shape: torch.Size([2, 16, 3, 224, 224])
# Labels: tensor([12, 28])

# %%
for label_idx in labels:
    for class_name, idx in label_map.items():
        if idx == label_idx.item():
            print(f"Label {label_idx.item()} corresponds to class: {class_name}")
# Out:
# Label 12 corresponds to class: Crow
# Label 28 corresponds to class: forget

# %%
# From (B, T, C, H, W) to (B, C, T, H, W)

for pixel_values, labels in train_loader:
    print("Before permute:", pixel_values.shape)
    pixel_values = pixel_values.permute(0, 2, 1, 3, 4)
    print("After permute:", pixel_values.shape)
    break
# Out:
# Before permute: torch.Size([2, 16, 3, 224, 224])
# After permute: torch.Size([2, 3, 16, 224, 224])

# %%
print(pixel_values.shape)
# Out:
# torch.Size([2, 3, 16, 224, 224])

# %%
print(f"Number of training videos: {len(train_dataset)}")
print(f"Number of validation videos: {len(val_dataset)}")
# Out:
# Number of training videos: 248
# Number of validation videos: 83

# %%
print(f"Number of training batches: {len(train_loader)}")
print(f"Number of validation batches: {len(val_loader)}")
# Out:
# Number of training batches: 124
# Number of validation batches: 42

# %%
print(f"Number of classes: {len(label_map)}")
# Out:
# Number of classes: 30

# %%
print(f"Label map: {label_map}")
# Out:
# Label map: {'A lot': 0, 'All of you': 1, 'Another': 2, 'Answer': 3, 'Around': 4, 'Ask': 5, 'Carefully': 6, 'Cat': 7, 'Chicken': 8, 'Collectin': 9, 'Cow': 10, 'Crocodile': 11, 'Crow': 12, 'Difficalty': 13, 'Dog': 14, 'Duck': 15, 'Elephant': 16, 'Everyday': 17, 'Everyone': 18, 'Fast': 19, 'Fear': 20, 'Feelings': 21, 'Follow': 22, 'brother': 23, 'cold': 24, 'come': 25, 'cut off': 26, 'feel hot': 27, 'forget': 28, 'forgive': 29}

# %% [markdown]
# Step 7: Adjust Model Output Layer

# %%
import torch.nn as nn

num_classes = len(label_map)
model.classifier = nn.Linear(model.classifier.in_features, num_classes)
model.config.num_labels = num_classes

# %% [markdown]
# Step 8: Training Loop with Validation & Best Model Saving

# %%
import torch
import torch.nn as nn
from torch.optim import AdamW
from sklearn.metrics import accuracy_score, classification_report

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
print(f"✅ Using device: {device}")

# Set loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = AdamW(model.parameters(), lr=5e-5)

# Save path for best model
best_val_loss = float('inf')
save_path = "/content/drive/MyDrive/ModelTrain/signlanguage/Model/TimeSformer_best_model.pth"

# Reverse label_map for readable class names
idx_to_class = {v: k for k, v in label_map.items()}

# Training loop
num_epochs = 10

for epoch in range(num_epochs):
    print(f"\n🎯 Epoch {epoch + 1}/{num_epochs}")
    model.train()
    train_loss = 0

    for pixel_values, labels in train_loader:
        pixel_values = pixel_values.to(device)
        labels = labels.to(device)

        outputs = model(pixel_values=pixel_values)
        loss = criterion(outputs.logits, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss += loss.item()

    avg_train_loss = train_loss / len(train_loader)

    # Validation
    model.eval()
    val_loss = 0
    true_labels = []
    pred_labels = []

    with torch.no_grad():
        for pixel_values, labels in val_loader:
            pixel_values = pixel_values.to(device)
            labels = labels.to(device)

            outputs = model(pixel_values=pixel_values)
            loss = criterion(outputs.logits, labels)
            val_loss += loss.item()

            preds = torch.argmax(outputs.logits, dim=1)
            true_labels.extend(labels.cpu().numpy())
            pred_labels.extend(preds.cpu().numpy())

    avg_val_loss = val_loss / len(val_loader)
    val_acc = accuracy_score(true_labels, pred_labels)

    print(f"📉 Train Loss: {avg_train_loss:.4f} | 📈 Val Loss: {avg_val_loss:.4f} | ✅ Val Acc: {val_acc*100:.2f}%")

    # Save best model
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        torch.save(model.state_dict(), save_path)
        print(f"💾 Best model saved with val loss {best_val_loss:.4f} to {save_path}")

    # Optional: Detailed classification report every epoch
    print("\n🧾 Classification Report:")
    print(classification_report(
        [idx_to_class[i] for i in true_labels],
        [idx_to_class[i] for i in pred_labels],
        digits=3
    ))
# Out:
# ✅ Using device: cuda
#
# 🎯 Epoch 1/10
# 📉 Train Loss: 3.1473 | 📈 Val Loss: 2.1793 | ✅ Val Acc: 32.53%
# 💾 Best model saved with val loss 2.1793 to /content/drive/MyDrive/ModelTrain/signlanguage/Model/TimeSformer_best_model.pth
#
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#        A lot      0.000     0.000     0.000         3
#   All of you      0.000     0.000     0.000         2
#      Another      0.000     0.000     0.000         3
#       Answer      0.500     0.333     0.400         3
#       Around      0.000     0.000     0.000         2
#          Ask      0.000     0.000     0.000         3
#    Carefully      0.000     0.000     0.000         3
#          Cat      0.000     0.000     0.000         3
#      Chicken      0.200     0.667     0.308         3
#    Collectin      0.000     0.000     0.000         2
#          Cow      1.000     1.000     1.000         3
#    Crocodile      0.286     1.000     0.444         2
#         Crow      0.000     0.000     0.000         3
#   Difficalty      0.300     1.000     0.462         3
#          Dog      0.750     1.000     0.857         3
#         Duck      0.000     0.000     0.000         3
#     Elephant      0.000     0.000     0.000         2
#     Everyday      0.000     0.000     0.000         2
#     Everyone      0.000     0.000     0.000         3
#         Fast      0.500     0.333     0.400         3
#         Fear      0.250     0.667     0.364         3
#     Feelings      0.300     1.000     0.462         3
#       Follow      0.273     1.000     0.429         3
#      brother      0.000     0.000     0.000         3
#         cold      0.000     0.000     0.000         3
#         come      1.000     0.333     0.500         3
#      cut off      0.000     0.000     0.000         3
#     feel hot      0.000     0.000     0.000         3
#       forget      0.500     0.500     0.500         2
#      forgive      1.000     0.667     0.800         3
#
#     accuracy                          0.325        83
#    macro avg      0.229     0.317     0.231        83
# weighted avg      0.238     0.325     0.239        83
#
#
# 🎯 Epoch 2/10
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 📉 Train Loss: 1.3992 | 📈 Val Loss: 1.2627 | ✅ Val Acc: 62.65%
# 💾 Best model saved with val loss 1.2627 to /content/drive/MyDrive/ModelTrain/signlanguage/Model/TimeSformer_best_model.pth
#
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#        A lot      1.000     0.333     0.500         3
#   All of you      0.000     0.000     0.000         2
#      Another      0.750     1.000     0.857         3
#       Answer      1.000     0.333     0.500         3
#       Around      1.000     0.500     0.667         2
#          Ask      1.000     1.000     1.000         3
#    Carefully      0.429     1.000     0.600         3
#          Cat      0.750     1.000     0.857         3
#      Chicken      0.000     0.000     0.000         3
#    Collectin      1.000     0.500     0.667         2
#          Cow      1.000     1.000     1.000         3
#    Crocodile      1.000     0.500     0.667         2
#         Crow      0.500     1.000     0.667         3
#   Difficalty      1.000     0.667     0.800         3
#          Dog      1.000     1.000     1.000         3
#         Duck      0.000     0.000     0.000         3
#     Elephant      0.000     0.000     0.000         2
#     Everyday      0.250     1.000     0.400         2
#     Everyone      0.000     0.000     0.000         3
#         Fast      0.000     0.000     0.000         3
#         Fear      1.000     0.667     0.800         3
#     Feelings      0.300     1.000     0.462         3
#       Follow      0.750     1.000     0.857         3
#      brother      0.429     1.000     0.600         3
#         cold      0.000     0.000     0.000         3
#         come      1.000     1.000     1.000         3
#      cut off      0.667     0.667     0.667         3
#     feel hot      1.000     0.667     0.800         3
#       forget      1.000     0.500     0.667         2
#      forgive      1.000     1.000     1.000         3
#
#     accuracy                          0.627        83
#    macro avg      0.627     0.611     0.568        83
# weighted avg      0.629     0.627     0.579        83
#
#
# 🎯 Epoch 3/10
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 📉 Train Loss: 0.3524 | 📈 Val Loss: 0.8004 | ✅ Val Acc: 73.49%
# 💾 Best model saved with val loss 0.8004 to /content/drive/MyDrive/ModelTrain/signlanguage/Model/TimeSformer_best_model.pth
#
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#        A lot      0.750     1.000     0.857         3
#   All of you      0.500     0.500     0.500         2
#      Another      1.000     1.000     1.000         3
#       Answer      1.000     1.000     1.000         3
#       Around      0.000     0.000     0.000         2
#          Ask      1.000     1.000     1.000         3
#    Carefully      1.000     1.000     1.000         3
#          Cat      1.000     1.000     1.000         3
#      Chicken      0.250     0.333     0.286         3
#    Collectin      0.250     1.000     0.400         2
#          Cow      1.000     1.000     1.000         3
#    Crocodile      0.000     0.000     0.000         2
#         Crow      0.600     1.000     0.750         3
#   Difficalty      1.000     1.000     1.000         3
#          Dog      1.000     1.000     1.000         3
#         Duck      0.000     0.000     0.000         3
#     Elephant      0.500     0.500     0.500         2
#     Everyday      0.000     0.000     0.000         2
#     Everyone      0.429     1.000     0.600         3
#         Fast      1.000     0.333     0.500         3
#         Fear      1.000     1.000     1.000         3
#     Feelings      1.000     0.333     0.500         3
#       Follow      0.750     1.000     0.857         3
#      brother      1.000     0.667     0.800         3
#         cold      1.000     1.000     1.000         3
#         come      1.000     0.333     0.500         3
#      cut off      1.000     0.667     0.800         3
#     feel hot      1.000     1.000     1.000         3
#       forget      0.500     0.500     0.500         2
#      forgive      0.750     1.000     0.857         3
#
#     accuracy                          0.735        83
#    macro avg      0.709     0.706     0.674        83
# weighted avg      0.748     0.735     0.707        83
#
#
# 🎯 Epoch 4/10
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 📉 Train Loss: 0.1074 | 📈 Val Loss: 0.6541 | ✅ Val Acc: 79.52%
# 💾 Best model saved with val loss 0.6541 to /content/drive/MyDrive/ModelTrain/signlanguage/Model/TimeSformer_best_model.pth
#
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#        A lot      1.000     1.000     1.000         3
#   All of you      0.333     0.500     0.400         2
#      Another      1.000     0.667     0.800         3
#       Answer      1.000     1.000     1.000         3
#       Around      1.000     1.000     1.000         2
#          Ask      1.000     0.667     0.800         3
#    Carefully      0.750     1.000     0.857         3
#          Cat      1.000     1.000     1.000         3
#      Chicken      0.000     0.000     0.000         3
#    Collectin      1.000     0.500     0.667         2
#          Cow      1.000     1.000     1.000         3
#    Crocodile      0.667     1.000     0.800         2
#         Crow      0.600     1.000     0.750         3
#   Difficalty      0.750     1.000     0.857         3
#          Dog      1.000     1.000     1.000         3
#         Duck      0.500     0.333     0.400         3
#     Elephant      0.667     1.000     0.800         2
#     Everyday      1.000     0.500     0.667         2
#     Everyone      0.600     1.000     0.750         3
#         Fast      1.000     0.333     0.500         3
#         Fear      0.750     1.000     0.857         3
#     Feelings      0.667     0.667     0.667         3
#       Follow      0.750     1.000     0.857         3
#      brother      1.000     0.667     0.800         3
#         cold      0.750     1.000     0.857         3
#         come      1.000     0.667     0.800         3
#      cut off      1.000     0.667     0.800         3
#     feel hot      1.000     1.000     1.000         3
#       forget      1.000     0.500     0.667         2
#      forgive      1.000     1.000     1.000         3
#
#     accuracy                          0.795        83
#    macro avg      0.826     0.789     0.778        83
# weighted avg      0.828     0.795     0.784        83
#
#
# 🎯 Epoch 5/10
# 📉 Train Loss: 0.0658 | 📈 Val Loss: 0.9802 | ✅ Val Acc: 74.70%
#
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#        A lot      0.750     1.000     0.857         3
#   All of you      0.500     1.000     0.667         2
#      Another      1.000     1.000     1.000         3
#       Answer      1.000     1.000     1.000         3
#       Around      0.250     0.500     0.333         2
#          Ask      1.000     0.667     0.800         3
#    Carefully      1.000     1.000     1.000         3
#          Cat      0.667     0.667     0.667         3
#      Chicken      0.000     0.000     0.000         3
#    Collectin      0.500     0.500     0.500         2
#          Cow      1.000     1.000     1.000         3
#    Crocodile      0.500     0.500     0.500         2
#         Crow      0.600     1.000     0.750         3
#   Difficalty      1.000     1.000     1.000         3
#          Dog      0.500     1.000     0.667         3
#         Duck      0.000     0.000     0.000         3
#     Elephant      1.000     0.500     0.667         2
#     Everyday      0.500     0.500     0.500         2
#     Everyone      0.600     1.000     0.750         3
#         Fast      1.000     0.333     0.500         3
#         Fear      0.750     1.000     0.857         3
#     Feelings      0.500     0.333     0.400         3
#       Follow      0.750     1.000     0.857         3
#      brother      1.000     1.000     1.000         3
#         cold      1.000     1.000     1.000         3
#         come      1.000     0.333     0.500         3
#      cut off      1.000     0.667     0.800         3
#     feel hot      1.000     1.000     1.000         3
#       forget      1.000     0.500     0.667         2
#      forgive      0.750     1.000     0.857         3
#
#     accuracy                          0.747        83
#    macro avg      0.737     0.733     0.703        83
# weighted avg      0.748     0.747     0.716        83
#
#
# 🎯 Epoch 6/10
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 📉 Train Loss: 0.0937 | 📈 Val Loss: 0.5819 | ✅ Val Acc: 84.34%
# 💾 Best model saved with val loss 0.5819 to /content/drive/MyDrive/ModelTrain/signlanguage/Model/TimeSformer_best_model.pth
#
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#        A lot      1.000     1.000     1.000         3
#   All of you      0.500     0.500     0.500         2
#      Another      1.000     1.000     1.000         3
#       Answer      1.000     1.000     1.000         3
#       Around      1.000     1.000     1.000         2
#          Ask      1.000     1.000     1.000         3
#    Carefully      0.600     1.000     0.750         3
#          Cat      1.000     1.000     1.000         3
#      Chicken      0.000     0.000     0.000         3
#    Collectin      1.000     1.000     1.000         2
#          Cow      1.000     1.000     1.000         3
#    Crocodile      1.000     1.000     1.000         2
#         Crow      0.500     0.667     0.571         3
#   Difficalty      1.000     1.000     1.000         3
#          Dog      1.000     1.000     1.000         3
#         Duck      0.667     0.667     0.667         3
#     Elephant      0.667     1.000     0.800         2
#     Everyday      1.000     0.500     0.667         2
#     Everyone      0.500     0.667     0.571         3
#         Fast      1.000     0.667     0.800         3
#         Fear      1.000     1.000     1.000         3
#     Feelings      1.000     0.667     0.800         3
#       Follow      1.000     1.000     1.000         3
#      brother      1.000     0.667     0.800         3
#         cold      0.750     1.000     0.857         3
#         come      0.667     0.667     0.667         3
#      cut off      1.000     1.000     1.000         3
#     feel hot      1.000     1.000     1.000         3
#       forget      1.000     0.500     0.667         2
#      forgive      1.000     1.000     1.000         3
#
#     accuracy                          0.843        83
#    macro avg      0.862     0.839     0.837        83
# weighted avg      0.860     0.843     0.840        83
#
#
# 🎯 Epoch 7/10
# 📉 Train Loss: 0.0627 | 📈 Val Loss: 0.7118 | ✅ Val Acc: 78.31%
#
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#        A lot      0.750     1.000     0.857         3
#   All of you      0.500     0.500     0.500         2
#      Another      1.000     1.000     1.000         3
#       Answer      1.000     0.667     0.800         3
#       Around      0.500     1.000     0.667         2
#          Ask      1.000     0.667     0.800         3
#    Carefully      0.600     1.000     0.750         3
#          Cat      1.000     1.000     1.000         3
#      Chicken      0.333     0.333     0.333         3
#    Collectin      1.000     0.500     0.667         2
#          Cow      1.000     1.000     1.000         3
#    Crocodile      1.000     0.500     0.667         2
#         Crow      0.600     1.000     0.750         3
#   Difficalty      1.000     1.000     1.000         3
#          Dog      1.000     1.000     1.000         3
#         Duck      0.000     0.000     0.000         3
#     Elephant      0.333     0.500     0.400         2
#     Everyday      0.500     0.500     0.500         2
#     Everyone      1.000     0.667     0.800         3
#         Fast      1.000     1.000     1.000         3
#         Fear      0.600     1.000     0.750         3
#     Feelings      1.000     0.333     0.500         3
#       Follow      0.750     1.000     0.857         3
#      brother      1.000     1.000     1.000         3
#         cold      1.000     1.000     1.000         3
#         come      1.000     0.333     0.500         3
#      cut off      0.750     1.000     0.857         3
#     feel hot      1.000     1.000     1.000         3
#       forget      1.000     0.500     0.667         2
#      forgive      0.750     1.000     0.857         3
#
#     accuracy                          0.783        83
#    macro avg      0.799     0.767     0.749        83
# weighted avg      0.808     0.783     0.763        83
#
#
# 🎯 Epoch 8/10
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 📉 Train Loss: 0.0551 | 📈 Val Loss: 0.7939 | ✅ Val Acc: 75.90%
#
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#        A lot      0.750     1.000     0.857         3
#   All of you      0.500     0.500     0.500         2
#      Another      1.000     1.000     1.000         3
#       Answer      1.000     1.000     1.000         3
#       Around      0.667     1.000     0.800         2
#          Ask      1.000     0.667     0.800         3
#    Carefully      0.600     1.000     0.750         3
#          Cat      1.000     1.000     1.000         3
#      Chicken      0.000     0.000     0.000         3
#    Collectin      0.500     0.500     0.500         2
#          Cow      1.000     1.000     1.000         3
#    Crocodile      0.000     0.000     0.000         2
#         Crow      0.667     0.667     0.667         3
#   Difficalty      1.000     0.667     0.800         3
#          Dog      1.000     1.000     1.000         3
#         Duck      0.333     1.000     0.500         3
#     Elephant      1.000     0.500     0.667         2
#     Everyday      1.000     0.500     0.667         2
#     Everyone      0.500     0.667     0.571         3
#         Fast      1.000     0.333     0.500         3
#         Fear      0.750     1.000     0.857         3
#     Feelings      0.667     0.667     0.667         3
#       Follow      0.750     1.000     0.857         3
#      brother      1.000     0.667     0.800         3
#         cold      0.750     1.000     0.857         3
#         come      1.000     0.333     0.500         3
#      cut off      1.000     1.000     1.000         3
#     feel hot      1.000     1.000     1.000         3
#       forget      1.000     0.500     0.667         2
#      forgive      1.000     1.000     1.000         3
#
#     accuracy                          0.759        83
#    macro avg      0.781     0.739     0.726        83
# weighted avg      0.791     0.759     0.742        83
#
#
# 🎯 Epoch 9/10
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 📉 Train Loss: 0.0654 | 📈 Val Loss: 0.6336 | ✅ Val Acc: 78.31%
#
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#        A lot      0.750     1.000     0.857         3
#   All of you      0.500     0.500     0.500         2
#      Another      1.000     1.000     1.000         3
#       Answer      1.000     1.000     1.000         3
#       Around      0.667     1.000     0.800         2
#          Ask      1.000     0.667     0.800         3
#    Carefully      0.600     1.000     0.750         3
#          Cat      1.000     1.000     1.000         3
#      Chicken      0.000     0.000     0.000         3
#    Collectin      0.000     0.000     0.000         2
#          Cow      1.000     1.000     1.000         3
#    Crocodile      0.500     0.500     0.500         2
#         Crow      0.600     1.000     0.750         3
#   Difficalty      1.000     1.000     1.000         3
#          Dog      0.750     1.000     0.857         3
#         Duck      0.000     0.000     0.000         3
#     Elephant      0.667     1.000     0.800         2
#     Everyday      0.000     0.000     0.000         2
#     Everyone      0.500     0.667     0.571         3
#         Fast      1.000     0.667     0.800         3
#         Fear      0.750     1.000     0.857         3
#     Feelings      1.000     0.667     0.800         3
#       Follow      1.000     1.000     1.000         3
#      brother      1.000     1.000     1.000         3
#         cold      1.000     1.000     1.000         3
#         come      1.000     0.333     0.500         3
#      cut off      1.000     1.000     1.000         3
#     feel hot      1.000     1.000     1.000         3
#       forget      1.000     1.000     1.000         2
#      forgive      1.000     1.000     1.000         3
#
#     accuracy                          0.783        83
#    macro avg      0.743     0.767     0.738        83
# weighted avg      0.765     0.783     0.757        83
#
#
# 🎯 Epoch 10/10
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 📉 Train Loss: 0.0194 | 📈 Val Loss: 0.5384 | ✅ Val Acc: 81.93%
# 💾 Best model saved with val loss 0.5384 to /content/drive/MyDrive/ModelTrain/signlanguage/Model/TimeSformer_best_model.pth
#
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#        A lot      1.000     1.000     1.000         3
#   All of you      0.500     1.000     0.667         2
#      Another      1.000     1.000     1.000         3
#       Answer      1.000     0.667     0.800         3
#       Around      0.667     1.000     0.800         2
#          Ask      1.000     0.667     0.800         3
#    Carefully      1.000     1.000     1.000         3
#          Cat      1.000     1.000     1.000         3
#      Chicken      0.000     0.000     0.000         3
#    Collectin      1.000     1.000     1.000         2
#          Cow      1.000     1.000     1.000         3
#    Crocodile      1.000     1.000     1.000         2
#         Crow      0.600     1.000     0.750         3
#   Difficalty      1.000     1.000     1.000         3
#          Dog      1.000     1.000     1.000         3
#         Duck      0.000     0.000     0.000         3
#     Elephant      1.000     0.500     0.667         2
#     Everyday      0.500     0.500     0.500         2
#     Everyone      0.600     1.000     0.750         3
#         Fast      1.000     0.667     0.800         3
#         Fear      0.750     1.000     0.857         3
#     Feelings      1.000     0.667     0.800         3
#       Follow      0.750     1.000     0.857         3
#      brother      1.000     1.000     1.000         3
#         cold      1.000     1.000     1.000         3
#         come      1.000     0.667     0.800         3
#      cut off      0.667     0.667     0.667         3
#     feel hot      1.000     1.000     1.000         3
#       forget      1.000     0.500     0.667         2
#      forgive      1.000     1.000     1.000         3
#
#     accuracy                          0.819        83
#    macro avg      0.834     0.817     0.806        83
# weighted avg      0.837     0.819     0.810        83

# %% [markdown]
# Load the best Model

# %%
best_model = "/content/drive/MyDrive/ModelTrain/signlanguage/Model/TimeSformer_best_model.pth"

# %%
from sklearn.metrics import accuracy_score, classification_report
import torch.nn as nn

def evaluate(model, dataloader, label_map, device):
    model.eval()
    criterion = nn.CrossEntropyLoss()
    val_loss = 0
    true_labels = []
    pred_labels = []

    with torch.no_grad():
        for pixel_values, labels in dataloader:
            pixel_values = pixel_values.to(device)
            labels = labels.to(device)

            outputs = model(pixel_values=pixel_values)
            loss = criterion(outputs.logits, labels)
            val_loss += loss.item()

            preds = torch.argmax(outputs.logits, dim=1)
            true_labels.extend(labels.cpu().numpy())
            pred_labels.extend(preds.cpu().numpy())

    avg_loss = val_loss / len(dataloader)
    accuracy = accuracy_score(true_labels, pred_labels)

    # Optional classification report (can print later)
    report = classification_report(
        [list(label_map.keys())[list(label_map.values()).index(i)] for i in true_labels],
        [list(label_map.keys())[list(label_map.values()).index(i)] for i in pred_labels],
        digits=3
    )

    return avg_loss, accuracy, report

# %%
# Load the best model
model.load_state_dict(torch.load(best_model))
model.eval()

# Run evaluation
avg_test_loss, test_acc, _ = evaluate(model, val_loader, label_map, device)

# Generate predictions for confusion matrix
true_labels = []
pred_labels = []

with torch.no_grad():
    for pixel_values, labels in val_loader:
        pixel_values = pixel_values.to(device)
        labels = labels.to(device)
        outputs = model(pixel_values=pixel_values)
        preds = torch.argmax(outputs.logits, dim=1)
        true_labels.extend(labels.cpu().numpy())
        pred_labels.extend(preds.cpu().numpy())

# Confusion matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

idx_to_class = {v: k for k, v in label_map.items()}
true_class_names = [idx_to_class[i] for i in true_labels]
pred_class_names = [idx_to_class[i] for i in pred_labels]

cm = confusion_matrix(true_class_names, pred_class_names, labels=list(idx_to_class.values()))
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d',
            xticklabels=idx_to_class.values(),
            yticklabels=idx_to_class.values(),
            cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()

# %%
from sklearn.metrics import accuracy_score

# Calculate and print accuracy
accuracy = accuracy_score(true_labels, pred_labels)
print(f"\n✅ Accuracy of the best saved model: {accuracy * 100:.2f}%")
# Out:
# ✅ Accuracy of the best saved model: 81.93%

# %%
# Make sure num_classes is still set correctly
model.classifier = nn.Linear(model.classifier.in_features, num_classes)
model.load_state_dict(torch.load(best_model))
model.eval()
model.to(device)
# Out:
# TimesformerForVideoClassification(
#   (timesformer): TimesformerModel(
#     (embeddings): TimesformerEmbeddings(
#       (patch_embeddings): TimesformerPatchEmbeddings(
#         (projection): Conv2d(3, 768, kernel_size=(16, 16), stride=(16, 16))
#       )
#       (pos_drop): Dropout(p=0.0, inplace=False)
#       (time_drop): Dropout(p=0.0, inplace=False)
#     )
#     (encoder): TimesformerEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x TimesformerLayer(
#           (drop_path): Identity()
#           (attention): TimeSformerAttention(
#             (attention): TimesformerSelfAttention(
#               (qkv): Linear(in_features=768, out_features=2304, bias=True)
#               (attn_drop): Dropout(p=0.0, inplace=False)
#             )
#             (output): TimesformerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): TimesformerIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): TimesformerOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (temporal_layernorm): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (temporal_attention): TimeSformerAttention(
#             (attention): TimesformerSelfAttention(
#               (qkv): Linear(in_features=768, out_features=2304, bias=True)
#               (attn_drop): Dropout(p=0.0, inplace=False)
#             )
#             (output): TimesformerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (temporal_dense): Linear(in_features=768, out_features=768, bias=True)
#         )
#       )
#     )
#     (layernorm): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#   )
#   (classifier): Linear(in_features=768, out_features=30, bias=True)
# )

# %%
def predict_video(video_path, model, feature_extractor, label_map, num_frames=16):
    # Load video frames
    vr = VideoReader(video_path, ctx=cpu(0))
    total_frames = len(vr)
    indices = np.linspace(0, total_frames - 1, min(num_frames, total_frames)).astype(int)
    frames = vr.get_batch(indices).asnumpy()

    # Preprocess
    inputs = feature_extractor(list(frames), return_tensors="pt")
    pixel_values = inputs["pixel_values"].to(device)

    # Inference
    with torch.no_grad():
        outputs = model(pixel_values)
        probs = torch.nn.functional.softmax(outputs.logits, dim=1)
        pred_class_idx = torch.argmax(probs, dim=1).item()

    # Map index to class name
    class_name = [k for k, v in label_map.items() if v == pred_class_idx][0]
    confidence = probs[0][pred_class_idx].item()
    return class_name, confidence

# %%
video_path = "/content/sign_dataset/Ask/s_34_w_043_a_30.mp4"  # <-- change this to your actual file
pred_class, confidence = predict_video(video_path, model, feature_extractor, label_map)
print(f"Predicted: {pred_class} ({confidence*100:.1f}%)")
# Out:
# Predicted: Ask (99.7%)

# %%
vr = VideoReader(video_path, ctx=cpu(0))
frames = vr.get_batch(np.linspace(0, len(vr)-1, 16).astype(int)).asnumpy()

import matplotlib.pyplot as plt

fig, axs = plt.subplots(4, 4, figsize=(12, 12))
for i, ax in enumerate(axs.flatten()):
    ax.imshow(frames[i])
    ax.axis('off')
plt.suptitle(f"Predicted: {pred_class} ({confidence*100:.1f}%)", fontsize=16)
plt.show()

# %% [markdown]
# Check Every Video

# %%
import os
from decord import VideoReader, cpu
import numpy as np
import torch.nn.functional as F

def predict_video(video_path, model, feature_extractor, label_map, num_frames=16):
    vr = VideoReader(video_path, ctx=cpu(0))
    total_frames = len(vr)
    indices = np.linspace(0, total_frames - 1, min(num_frames, total_frames)).astype(int)
    frames = vr.get_batch(indices).asnumpy()
    inputs = feature_extractor(list(frames), return_tensors="pt")
    pixel_values = inputs["pixel_values"].to(device)

    with torch.no_grad():
        outputs = model(pixel_values)
        probs = F.softmax(outputs.logits, dim=1)
        pred_idx = torch.argmax(probs, dim=1).item()
        confidence = probs[0][pred_idx].item()

    pred_class = [k for k, v in label_map.items() if v == pred_idx][0]
    return pred_class, confidence

# %%
dataset_root = "/content/sign_dataset"  # Change this to your dataset folder

for class_folder in os.listdir(dataset_root):
    folder_path = os.path.join(dataset_root, class_folder)
    if not os.path.isdir(folder_path):
        continue  # Skip non-folder files

    print(f"\n📂 Class folder: {class_folder}")

    for video_file in os.listdir(folder_path):
        if not video_file.endswith(".mp4"):
            continue
        video_path = os.path.join(folder_path, video_file)
        try:
            pred_class, confidence = predict_video(video_path, model, feature_extractor, label_map)
            print(f"📹 {video_file} → Predicted: {pred_class} ({confidence*100:.1f}%)")
        except Exception as e:
            print(f"⚠️ Failed on {video_file}: {e}")
# Out:
# 📂 Class folder: Answer
# 📹 s_34_w_124_a_30.mp4 → Predicted: Answer (99.4%)
# 📹 s_52_w_124_a_30.mp4 → Predicted: Answer (99.2%)
# 📹 s_14_w_124_a_30.mp4 → Predicted: Answer (99.3%)
# 📹 s_47_w_124_a_30.mp4 → Predicted: Answer (99.1%)
# 📹 s_40_w_124_a_30.mp4 → Predicted: Answer (88.6%)
# 📹 s_11_w_124_a_30.mp4 → Predicted: Answer (99.4%)
# 📹 s_53_w_124_a_30.mp4 → Predicted: cut off (50.1%)
# 📹 s_55_w_124_a_30.mp4 → Predicted: Answer (99.6%)
# 📹 s_56_w_124_a_30.mp4 → Predicted: Answer (98.7%)
# 📹 s_41_w_124_a_30.mp4 → Predicted: Answer (99.4%)
# 📹 s_54_w_124_a_30.mp4 → Predicted: Answer (99.3%)
#
# 📂 Class folder: Elephant
# 📹 s_51_w_65_s_90.mp4 → Predicted: Elephant (98.8%)
# 📹 s_35_w_065_a_90.mp4 → Predicted: Elephant (99.4%)
# 📹 s_26_w_65_s_90.mp4 → Predicted: Elephant (99.5%)
# 📹 s_39_w_065_a_90.mp4 → Predicted: Elephant (99.0%)
# 📹 s_34_w_065_a_90.mp4 → Predicted: Elephant (99.5%)
# 📹 s_50_w_065_a_90.mp4 → Predicted: Elephant (99.5%)
# 📹 s_37_w_065_a_90.mp4 → Predicted: Everyday (35.1%)
# 📹 s_11_w_065_a_90.mp4 → Predicted: Elephant (99.0%)
# 📹 s_36_w_065_a_90.mp4 → Predicted: Elephant (99.1%)
# 📹 s_18_w_065_a_90.mp4 → Predicted: Elephant (49.5%)
#
# 📂 Class folder: cold
# 📹 s_34_w_117_a_30.mp4 → Predicted: cold (99.1%)
# 📹 s_40_w_117_a_30.mp4 → Predicted: cold (99.3%)
# 📹 s_41_w_117_a_30.mp4 → Predicted: cold (52.1%)
# 📹 s_14_w_117_a_30.mp4 → Predicted: cold (95.5%)
# 📹 s_54_w_117_a_30.mp4 → Predicted: cold (99.2%)
# 📹 s_53_w_117_a_30.mp4 → Predicted: cold (99.1%)
# 📹 s_56_w_117_a_30.mp4 → Predicted: cold (83.5%)
# 📹 s_47_w_117_a_30.mp4 → Predicted: cold (99.2%)
# 📹 s_55_w_117_a_30.mp4 → Predicted: cold (99.1%)
# 📹 s_52_w_117_a_30.mp4 → Predicted: cold (99.4%)
# 📹 s_11_w_117_a_30.mp4 → Predicted: cold (99.2%)
#
# 📂 Class folder: Duck
# 📹 s_51_w_58_s_90.mp4 → Predicted: Duck (98.2%)
# 📹 s_26_w_58_s_90.mp4 → Predicted: Duck (98.0%)
# 📹 s_38_w_058_a_90.mp4 → Predicted: Duck (96.9%)
# 📹 s_36_w_058_a_90.mp4 → Predicted: Duck (98.2%)
# 📹 s_34_w_058_a_90.mp4 → Predicted: Chicken (59.4%)
# 📹 s_39_w_058_a_90.mp4 → Predicted: Chicken (74.5%)
# 📹 s_50_w_058_a_90.mp4 → Predicted: Duck (97.2%)
# 📹 s_11_w_058_a_90.mp4 → Predicted: Duck (97.5%)
# 📹 s_18_w_058_a_90.mp4 → Predicted: Chicken (65.5%)
# 📹 s_35_w_058_a_90.mp4 → Predicted: Duck (98.0%)
# 📹 s_37_w_058_a_90.mp4 → Predicted: Duck (98.2%)
#
# 📂 Class folder: All of you
# 📹 s_14_w_104_a_30.mp4 → Predicted: All of you (99.1%)
# 📹 s_55_w_104_a_30.mp4 → Predicted: All of you (67.0%)
# 📹 s_11_w_104_a_30.mp4 → Predicted: All of you (99.4%)
# 📹 s_34_w_104_a_30.mp4 → Predicted: All of you (98.7%)
# 📹 s_54_w_104_a_30.mp4 → Predicted: All of you (37.6%)
# 📹 s_52_w_104_a_30.mp4 → Predicted: All of you (98.9%)
# 📹 s_47_w_104_a_30.mp4 → Predicted: All of you (98.9%)
# 📹 s_41_w_104_a_30.mp4 → Predicted: All of you (98.7%)
# 📹 s_53_w_104_a_30.mp4 → Predicted: All of you (98.8%)
# 📹 s_40_w_104_a_30.mp4 → Predicted: All of you (98.7%)
#
# 📂 Class folder: cut off
# 📹 s_11_w_098_a_30.mp4 → Predicted: cut off (99.4%)
# 📹 s_54_w_098_a_30.mp4 → Predicted: cut off (99.4%)
# 📹 s_41_w_098_a_30.mp4 → Predicted: cut off (99.5%)
# 📹 s_47_w_098_a_30.mp4 → Predicted: All of you (34.1%)
# 📹 s_55_w_098_a_30.mp4 → Predicted: cut off (99.3%)
# 📹 s_53_w_098_a_30.mp4 → Predicted: cut off (99.4%)
# 📹 s_34_w_098_a_30.mp4 → Predicted: cut off (99.5%)
# 📹 s_56_w_098_a_30.mp4 → Predicted: cut off (99.5%)
# 📹 s_40_w_098_a_30.mp4 → Predicted: cut off (92.0%)
# 📹 s_14_w_098_a_30.mp4 → Predicted: cut off (94.8%)
# 📹 s_52_w_098_a_30.mp4 → Predicted: cut off (99.3%)
#
# 📂 Class folder: Follow
# 📹 s_34_w_044_a_30.mp4 → Predicted: Follow (99.5%)
# 📹 s_47_w_094_a_30.mp4 → Predicted: Follow (99.6%)
# 📹 s_41_w_094_a_30.mp4 → Predicted: Follow (99.7%)
# 📹 s_35_w_094_a_30.mp4 → Predicted: Follow (99.5%)
# 📹 s_46_w_094_a_30.mp4 → Predicted: Follow (98.1%)
# 📹 s_43_w_094_a_30.mp4 → Predicted: Follow (90.0%)
# 📹 s_54_w_094_a_30.mp4 → Predicted: Follow (99.5%)
# 📹 s_45_w_094_a_30.mp4 → Predicted: Follow (91.2%)
# 📹 s_42_w_094_a_30.mp4 → Predicted: Follow (99.6%)
# 📹 s_44_w_094_a_30.mp4 → Predicted: Follow (99.8%)
# 📹 s_34_w_094_a_30.mp4 → Predicted: Follow (99.6%)
# 📹 s_40_w_094_a_30.mp4 → Predicted: Follow (99.2%)
#
# 📂 Class folder: Fear
# 📹 s_45_w_089_a_30.mp4 → Predicted: Fear (97.4%)
# 📹 s_41_w_089_a_30.mp4 → Predicted: Fear (98.6%)
# 📹 s_40_w_089_a_30.mp4 → Predicted: Fear (99.5%)
# 📹 s_43_w_089_a_30.mp4 → Predicted: Fear (99.4%)
# 📹 s_44_w_089_a_30.mp4 → Predicted: Fear (99.4%)
# 📹 s_34_w_039_a_30.mp4 → Predicted: Fear (99.4%)
# 📹 s_47_w_089_a_30.mp4 → Predicted: Fear (99.4%)
# 📹 s_46_w_089_a_30.mp4 → Predicted: Fear (99.3%)
# 📹 s_34_w_089_a_30.mp4 → Predicted: Fear (99.5%)
# 📹 s_54_w_089_a_30.mp4 → Predicted: Fear (97.5%)
# 📹 s_42_w_089_a_30.mp4 → Predicted: Fear (99.5%)
#
# 📂 Class folder: forget
# 📹 s_40_w_030_a_30.mp4 → Predicted: forget (99.0%)
# 📹 s_53_w_030_a_30.mp4 → Predicted: forget (99.5%)
# 📹 s_14_w_030_a_30.mp4 → Predicted: forget (99.3%)
# 📹 s_52_w_030_a_30.mp4 → Predicted: forget (99.6%)
# 📹 s_11_w_030_a_30.mp4 → Predicted: forget (99.7%)
# 📹 s_34_w_030_a_30.mp4 → Predicted: Follow (28.7%)
# 📹 s_41_w_030_a_30.mp4 → Predicted: forget (99.4%)
# 📹 s_54_w_030_a_30.mp4 → Predicted: forget (92.0%)
# 📹 s_56_w_030_a_30.mp4 → Predicted: forget (99.5%)
# 📹 s_55_w_030_a_30.mp4 → Predicted: forget (99.4%)
#
# 📂 Class folder: Dog
# 📹 s_36_w_053_a_90.mp4 → Predicted: Dog (99.3%)
# 📹 s_38_w_053_a_90.mp4 → Predicted: Dog (99.4%)
# 📹 s_51_w_53_s_90.mp4 → Predicted: Dog (99.5%)
# 📹 s_18_w_053_a_90.mp4 → Predicted: Dog (98.0%)
# 📹 s_35_w_053_a_90.mp4 → Predicted: Dog (99.3%)
# 📹 s_34_w_053_a_90.mp4 → Predicted: Dog (99.3%)
# 📹 s_39_w_053_a_90.mp4 → Predicted: Dog (86.9%)
# 📹 s_11_w_053_a_90.mp4 → Predicted: Dog (99.4%)
# 📹 s_37_w_053_a_90.mp4 → Predicted: Dog (99.7%)
# 📹 s_26_w_53_s_90.mp4 → Predicted: Dog (99.6%)
# 📹 s_50_w_053_a_90.mp4 → Predicted: Dog (96.9%)
#
# 📂 Class folder: Everyone
# 📹 s_41_w_084_a_30.mp4 → Predicted: Everyone (83.0%)
# 📹 s_54_w_084_a_30.mp4 → Predicted: Everyone (99.4%)
# 📹 s_49_w_084_a_30.mp4 → Predicted: Everyone (95.4%)
# 📹 s_35_w_084_a_30 (3).mp4 → Predicted: Everyone (99.4%)
# 📹 s_42_w_084_a_30 (5).mp4 → Predicted: Everyone (99.4%)
# 📹 s_43_w_084_a_30.mp4 → Predicted: Everyone (99.4%)
# 📹 s_47_w_084_a_30.mp4 → Predicted: Everyone (99.2%)
# 📹 s_44_w_084_a_30.mp4 → Predicted: Everyone (99.4%)
# 📹 s_40_w_084_a_30 (1).mp4 → Predicted: Everyone (99.3%)
# 📹 s_46_w_084_a_30.mp4 → Predicted: Everyone (48.5%)
# 📹 s_34_w_084_a_30 (2).mp4 → Predicted: Everyone (99.4%)
# 📹 s_45_w_084_a_30.mp4 → Predicted: Everyone (99.0%)
#
# 📂 Class folder: Everyday
# 📹 s_26_w_78_s_90.mp4 → Predicted: Everyday (99.5%)
# 📹 s_50_w_078_a_90.mp4 → Predicted: Everyday (99.4%)
# 📹 s_37_w_078_a_90.mp4 → Predicted: Everyday (99.5%)
# 📹 s_18_w_078_a_90.mp4 → Predicted: Everyday (45.6%)
# 📹 s_35_w_078_a_90.mp4 → Predicted: Everyday (99.3%)
# 📹 s_11_w_078_a_90.mp4 → Predicted: Everyday (99.5%)
# 📹 s_51_w_78_s_90.mp4 → Predicted: Everyday (99.5%)
# 📹 s_39_w_078_a_90.mp4 → Predicted: Everyday (99.3%)
# 📹 s_36_w_078_a_90.mp4 → Predicted: Around (55.9%)
# 📹 s_34_w_078_a_90.mp4 → Predicted: Everyday (98.8%)
#
# 📂 Class folder: Ask
# 📹 s_44_w_093_a_30.mp4 → Predicted: Ask (99.7%)
# 📹 s_34_w_043_a_30.mp4 → Predicted: Ask (99.7%)
# 📹 s_42_w_093_a_30.mp4 → Predicted: Ask (96.8%)
# 📹 s_54_w_093_a_30.mp4 → Predicted: Ask (99.7%)
# 📹 s_47_w_093_a_30.mp4 → Predicted: Ask (99.3%)
# 📹 s_40_w_093_a_30.mp4 → Predicted: Ask (99.6%)
# 📹 s_43_w_093_a_30.mp4 → Predicted: Ask (99.3%)
# 📹 s_35_w_093_a_30.mp4 → Predicted: Fear (78.1%)
# 📹 s_41_w_093_a_30.mp4 → Predicted: Ask (99.6%)
# 📹 s_46_w_093_a_30.mp4 → Predicted: Ask (99.4%)
# 📹 s_34_w_093_a_30.mp4 → Predicted: Ask (99.6%)
# 📹 s_45_w_093_a_30.mp4 → Predicted: Ask (99.6%)
#
# 📂 Class folder: feel hot
# 📹 s_53_w_118_a_30.mp4 → Predicted: feel hot (98.9%)
# 📹 s_14_w_118_a_30.mp4 → Predicted: feel hot (99.5%)
# 📹 s_41_w_118_a_30.mp4 → Predicted: feel hot (99.5%)
# 📹 s_55_w_118_a_30.mp4 → Predicted: feel hot (99.5%)
# 📹 s_40_w_118_a_30.mp4 → Predicted: feel hot (83.1%)
# 📹 s_54_w_118_a_30.mp4 → Predicted: feel hot (99.6%)
# 📹 s_47_w_118_a_30.mp4 → Predicted: feel hot (90.1%)
# 📹 s_11_w_118_a_30.mp4 → Predicted: feel hot (99.4%)
# 📹 s_56_w_118_a_30.mp4 → Predicted: feel hot (99.2%)
# 📹 s_52_w_118_a_30.mp4 → Predicted: feel hot (99.5%)
# 📹 s_34_w_118_a_30.mp4 → Predicted: feel hot (91.3%)
#
# 📂 Class folder: forgive
# 📹 s_56_w_103_a_30.mp4 → Predicted: forgive (99.3%)
# 📹 s_54_w_103_a_30.mp4 → Predicted: forgive (99.5%)
# 📹 s_41_w_103_a_30.mp4 → Predicted: forgive (92.3%)
# 📹 s_47_w_103_a_30.mp4 → Predicted: forgive (87.4%)
# 📹 s_53_w_103_a_30.mp4 → Predicted: forgive (99.5%)
# 📹 s_14_w_103_a_30.mp4 → Predicted: forgive (99.5%)
# 📹 s_11_w_103_a_30.mp4 → Predicted: forgive (99.5%)
# 📹 s_52_w_103_a_30.mp4 → Predicted: forgive (99.3%)
# 📹 s_40_w_103_a_30.mp4 → Predicted: forgive (98.2%)
# 📹 s_34_w_103_a_30.mp4 → Predicted: forgive (99.5%)
# 📹 s_55_w_103_a_30.mp4 → Predicted: forgive (99.5%)
#
# 📂 Class folder: Collectin
# 📹 s_35_w_073_a_90.mp4 → Predicted: Collectin (78.0%)
# 📹 s_37_w_073_a_90.mp4 → Predicted: Collectin (99.1%)
# 📹 s_18_w_073_a_90.mp4 → Predicted: Collectin (99.2%)
# 📹 s_34_w_073_a_90.mp4 → Predicted: Collectin (99.4%)
# 📹 s_26_w_73_s_90.mp4 → Predicted: Collectin (99.6%)
# 📹 s_36_w_073_a_90.mp4 → Predicted: Collectin (99.4%)
# 📹 s_39_w_073_a_90.mp4 → Predicted: Collectin (99.5%)
# 📹 s_50_w_073_a_90.mp4 → Predicted: Collectin (75.9%)
# 📹 s_51_w_73_s_90.mp4 → Predicted: Collectin (99.5%)
# 📹 s_11_w_073_a_90.mp4 → Predicted: Collectin (99.3%)
#
# 📂 Class folder: Feelings
# 📹 s_46_w_086_a_30.mp4 → Predicted: Feelings (99.4%)
# 📹 s_45_w_086_a_30.mp4 → Predicted: Feelings (97.8%)
# 📹 s_54_w_086_a_30.mp4 → Predicted: Feelings (99.1%)
# 📹 s_44_w_086_a_30.mp4 → Predicted: Feelings (99.5%)
# 📹 s_43_w_086_a_30.mp4 → Predicted: Feelings (81.9%)
# 📹 s_40_w_086_a_30.mp4 → Predicted: Feelings (99.3%)
# 📹 s_49_w_086_a_30.mp4 → Predicted: Feelings (99.3%)
# 📹 s_41_w_086_a_30.mp4 → Predicted: Feelings (99.2%)
# 📹 s_35_w_086_a_30.mp4 → Predicted: Feelings (99.5%)
# 📹 s_34_w_086_a_30.mp4 → Predicted: Everyone (56.7%)
# 📹 s_42_w_086_a_30.mp4 → Predicted: Feelings (99.5%)
# 📹 s_47_w_086_a_30.mp4 → Predicted: Feelings (99.2%)
#
# 📂 Class folder: Another
# 📹 s_41_w_083_a_30.mp4 → Predicted: Another (99.5%)
# 📹 s_35_w_083_a_30.mp4 → Predicted: Another (99.7%)
# 📹 s_44_w_083_a_30.mp4 → Predicted: Another (99.4%)
# 📹 s_47_w_083_a_30.mp4 → Predicted: Another (99.3%)
# 📹 s_40_w_083_a_30.mp4 → Predicted: Another (99.3%)
# 📹 s_43_w_083_a_30.mp4 → Predicted: Another (99.5%)
# 📹 s_46_w_083_a_30.mp4 → Predicted: Another (99.3%)
# 📹 s_42_w_083_a_30.mp4 → Predicted: Another (99.7%)
# 📹 s_45_w_083_a_30.mp4 → Predicted: Another (99.6%)
# 📹 s_54_w_083_a_30.mp4 → Predicted: Another (94.5%)
# 📹 s_34_w_083_a_30.mp4 → Predicted: Another (59.0%)
# 📹 s_49_w_083_a_30.mp4 → Predicted: Another (52.3%)
#
# 📂 Class folder: Chicken
# 📹 s_34_w_059_a_90.mp4 → Predicted: Chicken (99.2%)
# 📹 s_26_w_59_s_90.mp4 → Predicted: Chicken (99.1%)
# 📹 s_38_w_059_a_90.mp4 → Predicted: Chicken (98.5%)
# 📹 s_35_w_059_a_90.mp4 → Predicted: Chicken (99.5%)
# 📹 s_50_w_059_a_90.mp4 → Predicted: Chicken (98.5%)
# 📹 s_18_w_059_a_90.mp4 → Predicted: Chicken (99.7%)
# 📹 s_39_w_059_a_90.mp4 → Predicted: Chicken (99.4%)
# 📹 s_11_w_059_a_90.mp4 → Predicted: Chicken (99.3%)
# 📹 s_36_w_059_a_90.mp4 → Predicted: Crow (94.4%)
# 📹 s_51_w_59_s_90.mp4 → Predicted: Duck (78.9%)
# 📹 s_37_w_059_a_90.mp4 → Predicted: Crow (77.6%)
#
# 📂 Class folder: come
# 📹 s_54_w_099_a_30.mp4 → Predicted: come (99.1%)
# 📹 s_55_w_099_a_30.mp4 → Predicted: come (97.1%)
# 📹 s_11_w_099_a_30.mp4 → Predicted: come (99.5%)
# 📹 s_52_w_099_a_30.mp4 → Predicted: come (99.3%)
# 📹 s_41_w_099_a_30.mp4 → Predicted: come (99.0%)
# 📹 s_34_w_099_a_30.mp4 → Predicted: come (99.6%)
# 📹 s_40_w_099_a_30.mp4 → Predicted: come (99.3%)
# 📹 s_56_w_099_a_30.mp4 → Predicted: come (99.4%)
# 📹 s_14_w_099_a_30.mp4 → Predicted: come (77.2%)
# 📹 s_47_w_099_a_30.mp4 → Predicted: come (99.3%)
# 📹 s_53_w_099_a_30.mp4 → Predicted: All of you (70.3%)
#
# 📂 Class folder: brother
# 📹 s_14_w_125_a_30.mp4 → Predicted: brother (99.3%)
# 📹 s_53_w_125_a_30.mp4 → Predicted: brother (99.2%)
# 📹 s_47_w_125_a_30.mp4 → Predicted: brother (86.2%)
# 📹 s_56_w_125_a_30.mp4 → Predicted: brother (99.5%)
# 📹 s_40_w_125_a_30.mp4 → Predicted: brother (99.5%)
# 📹 s_55_w_125_a_30.mp4 → Predicted: brother (99.1%)
# 📹 s_54_w_125_a_30.mp4 → Predicted: brother (99.5%)
# 📹 s_11_w_125_a_30.mp4 → Predicted: brother (99.5%)
# 📹 s_34_w_125_a_30.mp4 → Predicted: brother (99.6%)
# 📹 s_41_w_125_a_30.mp4 → Predicted: brother (99.5%)
# 📹 s_52_w_125_a_30.mp4 → Predicted: brother (47.1%)
#
# 📂 Class folder: Fast
# 📹 s_43_w_095_a_30.mp4 → Predicted: Fast (86.0%)
# 📹 s_47_w_095_a_30.mp4 → Predicted: Fast (99.1%)
# 📹 s_34_w_045_a_30.mp4 → Predicted: Fast (99.2%)
# 📹 s_54_w_095_a_30.mp4 → Predicted: Fast (39.7%)
# 📹 s_35_w_095_a_30.mp4 → Predicted: Fast (99.3%)
# 📹 s_42_w_095_a_30.mp4 → Predicted: Fast (99.2%)
# 📹 s_40_w_095_a_30.mp4 → Predicted: Fast (99.2%)
# 📹 s_46_w_095_a_30.mp4 → Predicted: Fast (99.4%)
# 📹 s_34_w_095_a_30.mp4 → Predicted: Fast (99.1%)
# 📹 s_45_w_095_a_30.mp4 → Predicted: Everyone (69.7%)
# 📹 s_44_w_095_a_30.mp4 → Predicted: Fast (99.2%)
# 📹 s_41_w_095_a_30.mp4 → Predicted: Fast (99.6%)
#
# 📂 Class folder: Cow
# 📹 s_39_w_051_a_90.mp4 → Predicted: Cow (97.5%)
# 📹 s_38_w_051_a_90.mp4 → Predicted: Cow (99.4%)
# 📹 s_11_w_051_a_90.mp4 → Predicted: Cow (99.3%)
# 📹 s_34_w_051_a_90.mp4 → Predicted: Cow (99.3%)
# 📹 s_18_w_051_a_90.mp4 → Predicted: Cow (99.0%)
# 📹 s_50_w_051_a_90.mp4 → Predicted: Cow (99.5%)
# 📹 s_37_w_051_a_90.mp4 → Predicted: Cow (82.1%)
# 📹 s_51_w_51_s_90.mp4 → Predicted: Cow (99.4%)
# 📹 s_36_w_051_a_90.mp4 → Predicted: Cow (99.4%)
# 📹 s_26_w_51_s_90.mp4 → Predicted: Cow (99.7%)
# 📹 s_35_w_051_a_90.mp4 → Predicted: Cow (99.6%)
#
# 📂 Class folder: Difficalty
# 📹 s_34_w_040_a_30.mp4 → Predicted: Difficalty (99.4%)
# 📹 s_47_w_090_a_30.mp4 → Predicted: Difficalty (99.6%)
# 📹 s_43_w_090_a_30.mp4 → Predicted: Difficalty (99.4%)
# 📹 s_45_w_090_a_30.mp4 → Predicted: Difficalty (99.4%)
# 📹 s_34_w_090_a_30.mp4 → Predicted: Difficalty (99.4%)
# 📹 s_54_w_090_a_30.mp4 → Predicted: Difficalty (99.4%)
# 📹 s_42_w_090_a_30.mp4 → Predicted: Difficalty (95.6%)
# 📹 s_44_w_090_a_30.mp4 → Predicted: Difficalty (99.4%)
# 📹 s_40_w_090_a_30.mp4 → Predicted: Difficalty (55.1%)
# 📹 s_41_w_090_a_30.mp4 → Predicted: Difficalty (99.4%)
# 📹 s_35_w_090_a_30.mp4 → Predicted: Difficalty (99.4%)
# 📹 s_46_w_090_a_30.mp4 → Predicted: Difficalty (95.2%)
#
# 📂 Class folder: Cat
# 📹 s_37_w_054_a_90.mp4 → Predicted: Cat (99.6%)
# 📹 s_34_w_054_a_90.mp4 → Predicted: Cat (99.1%)
# 📹 s_18_w_054_a_90.mp4 → Predicted: Cat (99.6%)
# 📹 s_50_w_054_a_90.mp4 → Predicted: Cat (99.5%)
# 📹 s_26_w_54_s_90.mp4 → Predicted: Cat (99.4%)
# 📹 s_36_w_054_a_90.mp4 → Predicted: Cat (99.5%)
# 📹 s_11_w_054_a_90.mp4 → Predicted: Cat (91.6%)
# 📹 s_39_w_054_a_90.mp4 → Predicted: Cat (98.8%)
# 📹 s_51_w_54_s_90.mp4 → Predicted: Cat (99.1%)
# 📹 s_38_w_054_a_90.mp4 → Predicted: Cat (99.1%)
# 📹 s_35_w_054_a_90.mp4 → Predicted: Cat (99.5%)
#
# 📂 Class folder: Around
# 📹 s_26_w_75_s_90.mp4 → Predicted: Around (99.5%)
# 📹 s_51_w_75_s_90.mp4 → Predicted: Around (99.4%)
# 📹 s_11_w_075_a_90.mp4 → Predicted: Around (99.4%)
# 📹 s_35_w_075_a_90.mp4 → Predicted: Around (99.6%)
# 📹 s_34_w_075_a_90.mp4 → Predicted: Around (98.8%)
# 📹 s_39_w_075_a_90.mp4 → Predicted: Around (99.6%)
# 📹 s_37_w_075_a_90.mp4 → Predicted: Around (99.1%)
# 📹 s_50_w_075_a_90.mp4 → Predicted: Around (99.1%)
# 📹 s_36_w_075_a_90.mp4 → Predicted: Around (71.5%)
# 📹 s_18_w_075_a_90.mp4 → Predicted: Around (83.6%)
#
# 📂 Class folder: Carefully
# 📹 s_41_w_085_a_30.mp4 → Predicted: Carefully (99.2%)
# 📹 s_35_w_085_a_30.mp4 → Predicted: Carefully (99.5%)
# 📹 s_45_w_085_a_30.mp4 → Predicted: Carefully (99.5%)
# 📹 s_43_w_085_a_30.mp4 → Predicted: Carefully (94.0%)
# 📹 s_47_w_085_a_30.mp4 → Predicted: Carefully (99.2%)
# 📹 s_42_w_085_a_30.mp4 → Predicted: Carefully (97.2%)
# 📹 s_46_w_085_a_30.mp4 → Predicted: Carefully (99.1%)
# 📹 s_54_w_085_a_30.mp4 → Predicted: Carefully (99.4%)
# 📹 s_49_w_085_a_30.mp4 → Predicted: Carefully (99.4%)
# 📹 s_34_w_085_a_30.mp4 → Predicted: Carefully (96.3%)
# 📹 s_44_w_085_a_30.mp4 → Predicted: Carefully (99.6%)
# 📹 s_40_w_085_a_30.mp4 → Predicted: Carefully (99.5%)
#
# 📂 Class folder: Crow
# 📹 s_26_w_60_s_90.mp4 → Predicted: Crow (97.0%)
# 📹 s_38_w_060_a_90.mp4 → Predicted: Crow (99.7%)
# 📹 s_39_w_060_a_90.mp4 → Predicted: Crow (98.4%)
# 📹 s_37_w_060_a_90.mp4 → Predicted: Crow (99.1%)
# 📹 s_11_w_060_a_90.mp4 → Predicted: Crow (99.4%)
# 📹 s_18_w_060_a_90.mp4 → Predicted: Crow (99.4%)
# 📹 s_51_w_60_s_90.mp4 → Predicted: Crow (99.6%)
# 📹 s_34_w_060_a_90.mp4 → Predicted: Crow (99.7%)
# 📹 s_36_w_060_a_90.mp4 → Predicted: Crow (99.7%)
# 📹 s_35_w_060_a_90.mp4 → Predicted: Crow (99.5%)
# 📹 s_50_w_060_a_90.mp4 → Predicted: Crow (77.2%)
#
# 📂 Class folder: A lot
# 📹 s_47_w_113_a_30.mp4 → Predicted: A lot (98.9%)
# 📹 s_11_w_113_a_30.mp4 → Predicted: A lot (99.2%)
# 📹 s_56_w_113_a_30.mp4 → Predicted: A lot (99.5%)
# 📹 s_54_w_113_a_30.mp4 → Predicted: A lot (84.2%)
# 📹 s_55_w_113_a_30.mp4 → Predicted: A lot (93.8%)
# 📹 s_34_w_113_a_30.mp4 → Predicted: A lot (99.4%)
# 📹 s_14_w_113_a_30.mp4 → Predicted: A lot (99.1%)
# 📹 s_40_w_113_a_30.mp4 → Predicted: A lot (90.5%)
# 📹 s_53_w_113_a_30.mp4 → Predicted: A lot (99.0%)
# 📹 s_41_w_113_a_30.mp4 → Predicted: A lot (99.2%)
# 📹 s_52_w_113_a_30.mp4 → Predicted: A lot (99.1%)
#
# 📂 Class folder: Crocodile
# 📹 s_36_w_068_a_90.mp4 → Predicted: Crocodile (99.2%)
# 📹 s_18_w_068_a_90.mp4 → Predicted: Crocodile (99.6%)
# 📹 s_39_w_068_a_90.mp4 → Predicted: Crocodile (99.5%)
# 📹 s_51_w_68_s_90.mp4 → Predicted: Crocodile (99.2%)
# 📹 s_34_w_068_a_90.mp4 → Predicted: Crocodile (99.3%)
# 📹 s_50_w_068_a_90.mp4 → Predicted: Crocodile (99.5%)
# 📹 s_11_w_068_a_90.mp4 → Predicted: Crocodile (53.1%)
# 📹 s_37_w_068_a_90.mp4 → Predicted: Crocodile (99.4%)
# 📹 s_35_w_068_a_90.mp4 → Predicted: Crocodile (99.6%)
# 📹 s_26_w_68_s_90.mp4 → Predicted: Crocodile (58.4%)
